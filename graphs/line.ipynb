# %% [markdown]
# # Line chart

# %%
import matplotlib.pyplot as plt

# %%
x = [ 1, 2, 5 ]
y = [ 1, 3, 7 ]
title = 'Meu gráfico'
axis_x = 'X axis'
axis_y = 'Y axis'

# %%
plt.title(title)

plt.xlabel(axis_x)
plt.ylabel(axis_y)

plt.plot(x, y)
# plt.show()
plt.savefig('nome_da_imagem.png', dpi=300) # png as default
